# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("admission.csv")

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
df.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  500.000000  500.000000   500.000000         500.000000  500.000000
# mean   250.500000  316.472000   107.192000           3.114000    3.374000
# std    144.481833   11.295148     6.081868           1.143512    0.991004
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    125.750000  308.000000   103.000000           2.000000    2.500000
# 50%    250.500000  317.000000   107.000000           3.000000    3.500000
# 75%    375.250000  325.000000   112.000000           4.000000    4.000000
# max    500.000000  340.000000   120.000000           5.000000    5.000000
#
#             LOR         CGPA    Research  Chance of Admit
# count  500.00000  500.000000  500.000000         500.00000
# mean     3.48400    8.576440    0.560000           0.72174
# std      0.92545    0.604813    0.496884           0.14114
# min      1.00000    6.800000    0.000000           0.34000
# 25%      3.00000    8.127500    0.000000           0.63000
# 50%      3.50000    8.560000    1.000000           0.72000
# 75%      4.00000    9.040000    1.000000           0.82000
# max      5.00000    9.920000    1.000000           0.97000

# %%
df.columns = df.columns.str.strip()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

custom_palette = ["#FF5733", "#33FF57"]

plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x="GRE Score", y="Chance of Admit", hue="Research", palette=custom_palette)
plt.title("GRE Score vs. Chance of Admit", fontsize=14)
plt.xlabel("GRE Score")
plt.ylabel("Chance of Admit")
plt.legend(title="Research")
plt.show()

# %%
custom_palette = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd"] 

plt.figure(figsize=(8, 6))
sns.barplot(data=avg_cgpa, x="University Rating", y="CGPA", palette=custom_palette)
plt.title("Average CGPA by University Rating", fontsize=14)
plt.xlabel("University Rating")
plt.ylabel("Average CGPA")
plt.show()
# Out:
# C:\Users\yasha\AppData\Local\Temp\ipykernel_19916\2163685585.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=avg_cgpa, x="University Rating", y="CGPA", palette=custom_palette)

# %%
# Box Plot: Distribution of SOP Scores by Research
custom_palette = ["#00876c", "#de425b"]  

plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x="Research", y="SOP", palette=custom_palette)
plt.title("Distribution of SOP Scores by Research", fontsize=14)
plt.xlabel("Research (0=No, 1=Yes)")
plt.ylabel("SOP Score")
plt.show()
# Out:
# C:\Users\yasha\AppData\Local\Temp\ipykernel_19916\2760568343.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="Research", y="SOP", palette=custom_palette)

# %%
# Pie Chart: Percentage of Applicants with and without Research
plt.figure(figsize=(8, 8))
research_counts = df["Research"].value_counts()
labels = ["No Research", "Has Research"]
plt.pie(research_counts, labels=labels, autopct='%1.1f%%', startangle=140, colors=["lightcoral", "skyblue"])
plt.title("Percentage of Applicants with and without Research", fontsize=14)
plt.show()

# %%
# Line Chart: Average Chance of Admit by GRE Score
plt.figure(figsize=(8, 6))
avg_admit = df.groupby("GRE Score")["Chance of Admit"].mean().reset_index()
sns.lineplot(data=avg_admit, x="GRE Score", y="Chance of Admit", color="orange")
plt.title("Average Chance of Admit by GRE Score", fontsize=14)
plt.xlabel("GRE Score")
plt.ylabel("Average Chance of Admit")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df["CGPA"], bins=20, kde=True, color="red")
plt.title("Distribution of CGPA Scores", fontsize=14)
plt.xlabel("CGPA")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(data=df, x="University Rating", y="GRE Score", palette="pastel")
plt.title("GRE Score Distribution by University Rating", fontsize=14)
plt.xlabel("University Rating")
plt.ylabel("GRE Score")
plt.show()
# Out:
# C:\Users\yasha\AppData\Local\Temp\ipykernel_12500\1720105187.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x="University Rating", y="GRE Score", palette="pastel")

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(), annot=True, cmap="rocket", fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap", fontsize=14)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x="University Rating", palette="magma")
plt.title("Number of Applicants per University Rating", fontsize=14)
plt.xlabel("University Rating")
plt.ylabel("Count")
plt.show()
# Out:
# C:\Users\yasha\AppData\Local\Temp\ipykernel_19916\1061746924.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x="University Rating", palette="magma")

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x="Research", y="CGPA", palette="coolwarm")
plt.title("CGPA Distribution by Research Experience", fontsize=14)
plt.xlabel("Research (0=No, 1=Yes)")
plt.ylabel("CGPA")
plt.show()
# Out:
# C:\Users\yasha\AppData\Local\Temp\ipykernel_12500\2856302898.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="Research", y="CGPA", palette="coolwarm")
